# %% [markdown]
# # modules

# %%
import math

# %%
from math import * #import everything/ don't recomended.
pow(7, 2)
# Out:
# 49.0

# %%
import math

pow = 8
pow(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import math
#       3 pow = 8
# ----> 4 pow(3)
#
# TypeError: 'int' object is not callable

# %%
import example #this is modele.

example.subtract(9, 3)
# Out:
# 6

# %% [markdown]
# ### Packages - a collection of modules

# %% [markdown]
# ## init.py
# bu fayl:
# papkani paket sifatida tanitadi
# qaysi funksiyalar tashqariga ochilishini belgilaydi.

# %%
mypackage/
__init__.py
greet.py
function.py

# %%
from my_package import functions, greet

functions.average(5, 7)
# Out:
# 6.0

# %%
from my_package.functions import average

average(10, 17)
# Out:
# 13.5

# %%
import math, random

math.factorial(5)
random.randint(1, 50)
# Out:
# 120

# %%
from papka import formatstr as fs, uniquelist as ul

fs.upperstr("alEX")
fs.format("MiKe")

ul.unique([1 ,12,13,34, 12, 22, 13])
# Out:
# [1, 34, 12, 13, 22]

# %% [markdown]
# ### Package installing -> pip

# %%
students = {
    "Ali": 85,
    "Vali": 90,
    "Sami": 78
}
students["Jorj"] = 56
students
# Out:
# {'Ali': 85, 'Vali': 90, 'Sami': 78, 'Jorj': 56}

# %%
students.get("Vali")
# Out:
# 90

# %%
students
# Out:
# dict

# %% [markdown]
# boolean operation

# %%
"a" == True
"b" == False
# Out:
# False

# %% [markdown]
# conditional statments shart operatorlari(if else elif)

# %% [markdown]
# # ATM day pul yechish

# %%
order_amount = int(input("order amountni kiriting"))
 
if order_amount>= 200000: 
    print("yetkazib berish bepul")
elif order_amount>=100000:
        print("yetkazib berish narxi 100000 so'm")
else:
        print("yetkazib berish narxi 200000 so'm")
# Out:
# yetkazib berish narxi 200000 so'm

# %% [markdown]
# # nesting conditionals
# there are number of if...else statements

# %% [markdown]
# ## class_work

# %%
number_input = int(input("raqam kiriting"))

if number_input % 2 == 0:
    print ("top emas")
else:
    print("toq son")
# Out:
# top emas

# %%
age = int(input("yoshinizni kiriting"))

if age < 0:
    print("Noto'g'ri yosh")
elif age < 18:
    print("Siz voyaga yetmagansiz")
elif age <=18 and age <60:
            print("Siz katta yoshda ekansiz")
else:
           print("Siz nafaqadasiz")
# Out:
# Siz nafaqadasiz

# %%
allowed_cars = ["Toyota", "Honda", "Ferrari"]
 
car = input("Mashina nomini kiriting").title()

if car in allowed_cars:
    print("Ruxsat berildi")
else:
    print("Ruxsat berilmadi")
# Out:
# Ruxsat berildi

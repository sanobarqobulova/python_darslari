# %% [markdown]
# append
# insert

# %% [markdown]
# clear#
# pop#index bilan
# remove#

# %% [markdown]
# sorting list

# %%
sorted_list
collection[]

# %% [markdown]
# list slicing

# %% [markdown]
# ### copying list

# %%
data_analytics=[]

collection = ["Hello", "Python", "SQL", 15, 37, "Power BI"]

data_analytics.append(collection[2])

data_analytics.append(collection[3])

data_analytics.append(collection[-1])

print (f"this tools {collection} are used for data analytics)")
# Out:
# this tools ['Hello', 'Python', 'SQL', 15, 37, 'Power BI'] are used for data analytics)

# %% [markdown]
# ### tuples

# %%
()#tuple
[]#list

# %% [markdown]
# tuple unpacking

# %%
t=(1,2,3,4,5)
*nums, y=t

# %%
t
# Out:
# (1, 2, 3, 4, 5)

# %%
y
# Out:
# 5

# %%
t=list(t)
t.append(6)
t
# Out:
# [1, 2, 3, 4, 5, 6]

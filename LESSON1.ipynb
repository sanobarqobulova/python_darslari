# %% [markdown]
# int,float,complex

# %%
#1
side=15#variable
print('perimetr:', side*4);

print('area:', side**2);
#2
diameter=32 #variable

import  math
print(math.pi)
print('length of circle:', math.pi *diameter);
#3

a=5 #variable
b=10 #variable

print('mean:', (a+b)/2) ;
#4
print('sum:', a+b) ;
#5
print('product:', a*b) ;

print('a^2:', a**2) ;

print('b^2:', b**2) ;
# Out:
# perimetr: 60
# area: 225
# 3.141592653589793
# length of circle: 100.53096491487338
# mean: 7.5
# sum: 15
# product: 50
# a^2: 25
# b^2: 100

# %% [markdown]
# # Python Dictionary and Set Exercises
#
# ## Dictionary Exercises
#
# ### 1. Sort a Dictionary by Value
# Write a Python script to sort (ascending and descending) a dictionary by value.

# %%
dic_movie_name = {"The Godfather": "crime", "Parasite": "Thriller", "Mission Impossible": "advanture", "The Lord of Rings": "advanture" }
 
print(sorted(dic_movie_name.values()))
# Out:
# ['Thriller', 'advanture', 'advanture', 'crime']

# %%
dic_movie_name = {"The Godfather": "crime", "Parasite": "Thriller", "Mission Impossible": "advanture", "The Lord of Rings": "advanture" }
print(sorted(dic_movie_name.values(), reverse = True))
# Out:
# ['crime', 'advanture', 'advanture', 'Thriller']

# %% [markdown]
# ### 2. Add a Key to a Dictionary
# Write a Python script to add a key to a dictionary.
#
# **Sample Dictionary:**
# ```python
# {0: 10, 1: 20}
# ```
#
# **Expected Result:**
# ```python
# {0: 10, 1: 20, 2: 30}

# %%
num = {0: 10, 1: 20}#0 is key, 10 is a value

num[2]=30
num
# Out:
# {0: 10, 1: 20, 2: 30}

# %% [markdown]
# ### 3. Concatenate Multiple Dictionaries
# Write a Python script to concatenate the following dictionaries to create a new one.
#
# **Sample Dictionaries:**
# ```python
# dic1 = {1: 10, 2: 20}
# dic2 = {3: 30, 4: 40}
# dic3 = {5: 50, 6: 60}
# ```
#
# **Expected Result:**
# ```python
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
dic1 = {1: 10, 2: 20}
dic2 = {3: 30, 4: 40}
dic3 = {5: 50, 6: 60}

# %%
dic4 = dic1| dic2| dic3 #concanate multiple dictionaries
print(dic4)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %% [markdown]
# ### 4. Generate a Dictionary with Squares
# Write a Python script to generate and print a dictionary that contains a number (between 1 and n) in the form `(x, x*x)`.
#
# **Sample Dictionary (n = 5):**
# ```python
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
dic_squares = {}

for x in range(1,6):
    
    dic_squares[x] = x*x

# %%
dic_squares
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# ### 5. Dictionary of Squares (1 to 15)
# Write a Python script to print a dictionary where the keys are numbers between 1 and 15 (both included) and the values are the square of the keys.
#
# **Expected Output:**
# ```python
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}

# %%
squares = {}

for number in range(1,16):
    squares[number] = number * number

# %%
squares
# Out:
# {1: 1,
#  2: 4,
#  3: 9,
#  4: 16,
#  5: 25,
#  6: 36,
#  7: 49,
#  8: 64,
#  9: 81,
#  10: 100,
#  11: 121,
#  12: 144,
#  13: 169,
#  14: 196,
#  15: 225}

# %% [markdown]
# ## Set Exercises
#
# ### 1. Create a Set
# Write a Python program to create a set.

# %%
my_set = {1,2,3,4,5,6,7}
my_set
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %% [markdown]
# ### 2. Iterate Over a Set
# Write a Python program to iterate over sets.

# %%
num_set = {1,2,4,7,8,5,7}
for number in num_set:
    print(number)
# Out:
# 1
# 2
# 4
# 5
# 7
# 8

# %% [markdown]
# ### 3. Add Member(s) to a Set
# Write a Python program to add member(s) to a set.

# %%
set_mem = {"Jorj", "Milan", "Washington", "Philipp"}
set_mem.add("Michel")
set_mem
# Out:
# {'Jorj', 'Michel', 'Milan', 'Philipp', 'Washington'}

# %% [markdown]
# ### 4. Remove Item(s) from a Set
# Write a Python program to remove item(s) from a given set.

# %%
set_item = {1,3,5,7,5,8,0}
set_item.discard(1)#removes exact 1
set_item
# Out:
# {0, 3, 5, 7, 8}

# %% [markdown]
# ### 5. Remove an Item if Present in the Set
# Write a Python program to remove an item from a set if it is present in the set.

# %%
set_item2 = {"a", 3, "b", 5, "d", 4, "c", 8, "e", 9, "f"}
set_item2.discard("a")
set_item2
# Out:
# {3, 4, 5, 8, 9, 'b', 'c', 'd', 'e', 'f'}
